# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("brain_stroke.csv", sep=",")

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
gender = df["gender"]

# %%
gender_counts=gender.value_counts()

# %%
gender_counts.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
Married = df["ever_married"]

# %%
Married_counts=Married.value_counts()

# %%
Married_counts.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='ever_married'>

# %%
ax = sns.countplot(x="gender",data=df)

# %%
ax = sns.countplot(x="ever_married",data=df)

# %%
f, ax = plt.subplots(1,2, figsize=(18,8))
df["stroke"].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0], shadow = True)
ax[0].set_title('had stroke')
ax[0].set_ylabel('')
sns.countplot(x="stroke",data=df)
ax[1].set_title('had stroke')
plt.show()

# %%
f, ax = plt.subplots(1,2, figsize=(10,7))
df[["gender","stroke"]].groupby(['gender']).mean().plot.bar(ax=ax[0])
ax[0].set_title('had stroke vs gender')
sns.countplot("gender", hue='stroke', data=df, ax=ax[1])
ax[1].set_title('Gender: Had a stroke vs not had a stroke')
plt.show()
# Out:
# c:\Users\strut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f, ax = plt.subplots(1,2, figsize=(19,7))
df[["smoking_status"]].value_counts().plot.bar(color=['blue', 'red', 'green', 'cyan'], ax=ax[0])
ax[0].set_title('Number of people had a stroke by smoking status')
sns.countplot("smoking_status", hue='stroke', data=df, ax=ax[1])
ax[1].set_title('Smoking Status: Had a stroke vs not had a stroke')
plt.show()
# Out:
# c:\Users\strut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f, ax = plt.subplots(1,2, figsize=(19,7))
df[["hypertension","stroke"]].groupby(['hypertension']).mean().plot.bar(ax=ax[0])
ax[0].set_title('had stroke vs hypertension')
sns.countplot("hypertension", hue='stroke', data=df, ax=ax[1])
ax[1].set_title('Hypertension: Had a stroke vs not had a stroke')
plt.show()
# Out:
# c:\Users\strut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f, ax = plt.subplots(1,2, figsize=(19,7))
df[["heart_disease","stroke"]].groupby(['heart_disease']).mean().plot.bar(ax=ax[0])
ax[0].set_title('had stroke vs heart disease')
sns.countplot("heart_disease", hue='stroke', data=df, ax=ax[1])
ax[1].set_title('Heart disease: Had a stroke vs not had a stroke')
plt.show()
# Out:
# c:\Users\strut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
